# %%
### <div class="alert alert-block alert-info"><b>Import library<b><div>

# %%
# matplotlib → visualization

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display all columns
pd.set_option('display.max_columns', None)

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
### <div class="alert alert-block alert-info"><b>Load Cleaned Dataset<b><div>

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nFiles in Current Folder:")
print(os.listdir())
# Out:
# Current Folder:
# C:\Users\Akash\IPL Project
#
# Files in Current Folder:
# ['.ipynb_checkpoints', '01_Data_Understanding.ipynb', '02_Data_Cleaning.ipynb', '03_EDA.ipynb', '04_Advance analysis.ipynb', '05_Strategic_Insights_Dashboard.ipynb', '06_Final_Insights_Report.ipynb', 'deliveries_checked.csv', 'deliveries_cleaned.csv', 'IPL.ipynb', 'ipl_dataset_cleaned.csv', 'matches_checked.csv', 'top_batters_chart.png', 'top_batters_summary.csv', 'top_bowlers_summary.csv', 'venue_strategy_summary.csv']

# %%
# Load Cleaned ipl_data dataset
ipl_data=pd.read_csv( r"C:\Users\Akash\Downloads\IPL-Data-Analysis-Project\Datasets\ipl_dataset_cleaned.csv",low_memory=False)

# %%
# Load Cleaned ipl_data dataset
ipl_data=pd.read_csv( r"C:\Users\Akash\Downloads\IPL-Data-Analysis-Project\Datasets\ipl_dataset_cleaned.csv",low_memory=False)

# %%
i=pd.read_csv(
"../Downloads/IPL-Data-Analysis-Project/Datasets/ipl_dataset_cleaned.csv",
low_memory=False)
i.shape
# Out:
# (251580, 39)

# %%
### <div class="alert alert-block alert-info"><b>Basic Overview<b><div>

# %%
# First few rows

ipl_data.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# 0           1     legbyes          0          Not Out        Not Out     NaN
# 1           0    No Extra          0          Not Out        Not Out     NaN
# 2           1       wides          0          Not Out        Not Out     NaN
# 3           0    No Extra          0          Not Out        Not Out     NaN
# 4           0    No Extra          0          Not Out        Not Out     NaN
#
#   match_phase  is_super_over   season       city        date match_type  \
# 0   Powerplay              0  2007/08  Bengaluru  2008-04-18     League
# 1   Powerplay              0  2007/08  Bengaluru  2008-04-18     League
# 2   Powerplay              0  2007/08  Bengaluru  2008-04-18     League
# 3   Powerplay              0  2007/08  Bengaluru  2008-04-18     League
# 4   Powerplay              0  2007/08  Bengaluru  2008-04-18     League
#
#   player_of_match                              venue  \
# 0     BB McCullum  M. Chinnaswamy Stadium, Bengaluru
# 1     BB McCullum  M. Chinnaswamy Stadium, Bengaluru
# 2     BB McCullum  M. Chinnaswamy Stadium, Bengaluru
# 3     BB McCullum  M. Chinnaswamy Stadium, Bengaluru
# 4     BB McCullum  M. Chinnaswamy Stadium, Bengaluru
#
#                          team1                  team2  \
# 0  Royal Challengers Bengaluru  Kolkata Knight Riders
# 1  Royal Challengers Bengaluru  Kolkata Knight Riders
# 2  Royal Challengers Bengaluru  Kolkata Knight Riders
# 3  Royal Challengers Bengaluru  Kolkata Knight Riders
# 4  Royal Challengers Bengaluru  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bengaluru         field  Kolkata Knight Riders   runs
# 1  Royal Challengers Bengaluru         field  Kolkata Knight Riders   runs
# 2  Royal Challengers Bengaluru         field  Kolkata Knight Riders   runs
# 3  Royal Challengers Bengaluru         field  Kolkata Knight Riders   runs
# 4  Royal Challengers Bengaluru         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over  method    umpire1  \
# 0          140.0        223.0          20.0          N  Normal  Asad Rauf
# 1          140.0        223.0          20.0          N  Normal  Asad Rauf
# 2          140.0        223.0          20.0          N  Normal  Asad Rauf
# 3          140.0        223.0          20.0          N  Normal  Asad Rauf
# 4          140.0        223.0          20.0          N  Normal  Asad Rauf
#
#        umpire2  year
# 0  RE Koertzen  2008
# 1  RE Koertzen  2008
# 2  RE Koertzen  2008
# 3  RE Koertzen  2008
# 4  RE Koertzen  2008

# %%
# Dataset information

ipl_data.info()

# %%
### <div class="alert alert-block alert-info"><b>EDA-1 — Matches Played Per Year<b><div>

# %%
# MATCHES PER YEAR


matches_per_year = ipl_data.groupby("year")["match_id"].nunique()

plt.figure(figsize=(8,6))

plt.plot(

    matches_per_year.index,

    matches_per_year.values,

    marker="o"
)

plt.title("Number of Matches Per Year")

plt.xlabel("Year")

plt.ylabel("Matches")

plt.grid()

plt.show()

# %%
### <div class="alert alert-block alert-info"><b>EDA-2 matches Per venue<b><div>

# %%
# ==========================================
# MATCHES PER VENUE
# ==========================================

venue_matches = ipl_data.groupby("venue")["match_id"].nunique().sort_values(ascending=False)

plt.figure(figsize=(16,10))

plt.bar(

    venue_matches.index,

    venue_matches.values
)

plt.xticks(rotation=90)

plt.title("Matches Played Per Venue")

plt.xlabel("Venue")

plt.ylabel("Matches")

plt.tight_layout()

plt.show()

# %%
### <div class="alert alert-block alert-info"><b>EDA -3 Toss Decision Analysis<b><div>

# %%
# ==========================================
# TOSS DECISION ANALYSIS
# ==========================================



toss_counts = ipl_data.groupby(
    "toss_decision"
)["match_id"].nunique()

toss_percent = (

    toss_counts /
    toss_counts.sum()

) * 100


plt.figure(figsize=(6,6))

plt.bar(
    toss_percent.index,
    toss_percent.values
)

plt.title("Toss Decision Percentage")
plt.xlabel("Decision")
plt.ylabel("Percentage")

plt.show()

# %%
### <div class="alert alert-block alert-info"><b>EDA - 4 Top 10 Batsmen (Total Runs)<b><div>

# %%
# ==========================================
# BATTER PERFORMANCE METRICS
# ==========================================

# Total runs scored

batter_runs = ipl_data.groupby("batter")["batsman_runs"].sum()


# Matches played

batter_matches = ipl_data.groupby("batter")["match_id"].nunique()


# Balls faced

batter_balls = ipl_data.groupby("batter")["ball"].count()


# Times out

batter_outs = ipl_data[
    
    ipl_data["player_dismissed"] != "Not Out"

].groupby(
    
    "batter"

)["player_dismissed"].count()



# Strike Rate

strike_rate = ( batter_runs / batter_balls) * 100


# Batting Average

batting_average = (batter_runs / batter_outs )


# Runs per Match

runs_per_match = ( batter_runs /  batter_matches)


# Combine into dataframe

batter_stats = pd.DataFrame({

    "Runs": batter_runs,

    "Matches": batter_matches,

    "Balls": batter_balls,

    "Strike Rate": strike_rate,

    "Average": batting_average,

    "Runs per Match": runs_per_match

})


# Minimum match filter

batter_stats = batter_stats[
    
    batter_stats["Matches"] >= 30

]


batter_stats.head()

# %%
# ==========================================
# TOP BATTERS
# ==========================================

top_batters = batter_stats.sort_values(
    
    by=["Runs", "Average", "Strike Rate"],
    
    ascending=False

).head(10)


top_batters

# %%
plt.figure(figsize=(10,6))

top_batters["Runs"].plot(
    
    kind="bar",
    color="RGB: 255, 165, 0"
)

plt.title( "Top 10 Batters ")

plt.ylabel("Runs")

plt.xticks(rotation=75)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 plt.figure(figsize=(10,6))
# ----> 3 top_batters["Runs"].plot(
#       4
#       5     kind="bar",
#       6     color="RGB: 255, 165, 0"
#       7 )
#       9 plt.title( "Top 10 Batters ")
#      11 plt.ylabel("Runs")
#
# NameError: name 'top_batters' is not defined

# %% [markdown]
# ### <div class="alert alert-block alert-info"><b>EDA 5 = Top 10 Bowlers (Total Runs)<b><div>

# %%
# ==========================================
# BOWLER PERFORMANCE METRICS
# ==========================================

# Total wickets

bowler_wickets = ipl_data[

    ipl_data["is_wicket"] == 1

].groupby(
    
    "bowler"

)["is_wicket"].count()



# Runs conceded

bowler_runs = ipl_data.groupby("bowler")["total_runs"].sum()


# Balls bowled

bowler_balls = ipl_data.groupby( "bowler" )["ball"].count()


# Overs bowled

bowler_overs = bowler_balls / 6


# Matches played

bowler_matches = ipl_data.groupby( "bowler" )["match_id"].nunique()


# Economy Rate

economy = ( bowler_runs / bowler_overs)


# Bowling Average

bowling_average = ( bowler_runs / bowler_wickets)


# Wickets per Match

wickets_per_match = ( bowler_wickets / bowler_matches )


# Combine dataframe

bowler_stats = pd.DataFrame({

    "Wickets": bowler_wickets,

    "Matches": bowler_matches,

    "Economy": economy,

    "Average": bowling_average,

    "Wickets per Match": wickets_per_match

})


# Minimum match filter

bowler_stats = bowler_stats[
    
    bowler_stats["Matches"] >= 30

]


bowler_stats.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       1 # ==========================================
#       2 # BOWLER PERFORMANCE METRICS
#       3 # ==========================================
#       4
#       5 # Total wickets
# ----> 7 bowler_wickets = ipl_data[
#       8
#       9     ipl_data["is_wicket"] == 1
#      10
#      11 ].groupby(
#      12
#      13     "bowler"
#      14
#      15 )["is_wicket"].count()
#      19 # Runs conceded
#      21 bowler_runs = ipl_data.groupby("bowler")["total_runs"].sum()
#
# NameError: name 'ipl_data' is not defined

# %%
# ==========================================
# TOP BOWLERS 
# ==========================================

top_bowlers = bowler_stats.sort_values(
    
    by=["Wickets", "Economy"],
    
    ascending=[False, True]

).head(10)


top_bowlers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 # ==========================================
#       2 # TOP BOWLERS
#       3 # ==========================================
# ----> 5 top_bowlers = bowler_stats.sort_values(
#       6
#       7     by=["Wickets", "Economy"],
#       8
#       9     ascending=[False, True]
#      10
#      11 ).head(10)
#      14 top_bowlers
#
# NameError: name 'bowler_stats' is not defined

# %%
plt.figure(figsize=(10,6))

top_bowlers["Wickets"].plot(
    
    kind="bar",
    color="purple"
)

plt.title("Top 10 Bowlers (Normalized)")

plt.xlabel("Bowler")

plt.ylabel("Wickets")

plt.xticks(rotation=75)

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 plt.figure(figsize=(10,6))
# ----> 3 top_bowlers["Wickets"].plot(
#       4
#       5     kind="bar",
#       6     color="purple"
#       7 )
#       9 plt.title("Top 10 Bowlers (Normalized)")
#      11 plt.xlabel("Bowler")
#
# NameError: name 'top_bowlers' is not defined

# %% [markdown]
# ### <div class="alert alert-block alert-info"><b>EDA - 6 = RUNS PER MATCH PHASE<b><div>

# %%
# ==========================================
# RUNS BY MATCH PHASE (ORDERED)
# ==========================================

# Step 1 — Group total runs by phase

phase_runs = ipl_data.groupby("match_phase")["total_runs"].sum()

# Step 2 — Define correct phase order

phase_order = ["Powerplay","Middle Overs","Death Overs"]

# Step 3 — Reorder phases

phase_runs = phase_runs.reindex(phase_order)

# Step 4 — Plot

plt.figure(figsize=(4,4))

plt.bar(
    phase_runs.index,

    phase_runs.values
)

plt.title("Total Runs by Match Phase")

plt.xlabel("Match Phase")

plt.ylabel("Total Runs")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       1 # ==========================================
#       2 # RUNS BY MATCH PHASE (ORDERED)
#       3 # ==========================================
#       4
#       5 # Step 1 — Group total runs by phase
# ----> 7 phase_runs = ipl_data.groupby("match_phase")["total_runs"].sum()
#       9 # Step 2 — Define correct phase order
#      11 phase_order = ["Powerplay","Middle Overs","Death Overs"]
#
# NameError: name 'ipl_data' is not defined

# %% [markdown]
# ### <div class="alert alert-block alert-info"><b>EDA - 7 Team Winning Count<b><div>

# %%
# ==========================================
# TEAM WINNING COUNT
# ==========================================

team_wins = ipl_data.groupby("winner")["match_id"].nunique().sort_values(ascending=False)

plt.figure(figsize=(12,6))

plt.bar(
    team_wins.index,

    team_wins.values
)

plt.xticks(rotation=90)

plt.title("Matches Won by Teams")

plt.xlabel("Team")

plt.ylabel("Wins")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 # ==========================================
#       2 # TEAM WINNING COUNT
#       3 # ==========================================
# ----> 5 team_wins = ipl_data.groupby("winner")["match_id"].nunique().sort_values(ascending=False)
#       7 plt.figure(figsize=(12,6))
#       9 plt.bar(
#      10     team_wins.index,
#      11
#      12     team_wins.values
#      13 )
#
# NameError: name 'ipl_data' is not defined

# %% [markdown]
# ### <div class="alert alert-block alert-info"><b>EDA - 8 Super Over Analysis<b><div>

# %%
# ==========================================
# SUPER OVER ANALYSIS
# ==========================================

super_over_count = ipl_data.groupby("is_super_over")["match_id"].nunique()

plt.figure(figsize=(4,6))

plt.bar(

    ["Normal", "Super Over"],

    super_over_count.values

)

plt.title(
    "Super Over Matches"
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       1 # ==========================================
#       2 # SUPER OVER ANALYSIS
#       3 # ==========================================
# ----> 5 super_over_count = ipl_data.groupby("is_super_over")["match_id"].nunique()
#       7 plt.figure(figsize=(4,6))
#       9 plt.bar(
#      10
#      11     ["Normal", "Super Over"],
#    (...)
#      14
#      15 )
#
# NameError: name 'ipl_data' is not defined

# %% [markdown]
# ### <div class="alert alert-block alert-info"><b>EDA - 9 Average Runs Per Over<b><div>

# %%
# ==========================================
# AVERAGE RUNS PER OVER
# ==========================================

runs_per_over = ipl_data.groupby(
    "over"
)["total_runs"].mean()


plt.figure(figsize=(12,6))

plt.plot(

    runs_per_over.index,

    runs_per_over.values,

    marker="D",
    markerfacecolor="Green"

)
plt.xticks(range(1,21))

plt.title(
    "Average Runs Per Over"
)

plt.xlabel("Over")

plt.ylabel("Runs")

plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 # ==========================================
#       2 # AVERAGE RUNS PER OVER
#       3 # ==========================================
# ----> 5 runs_per_over = ipl_data.groupby(
#       6     "over"
#       7 )["total_runs"].mean()
#      10 plt.figure(figsize=(12,6))
#      12 plt.plot(
#      13
#      14     runs_per_over.index,
#    (...)
#      20
#      21 )
#
# NameError: name 'ipl_data' is not defined
